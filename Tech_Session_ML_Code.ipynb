# %% [markdown]
# # **#Employee Salary Prediction using adult csv**

# %%
#load your libraries

import pandas as pd
data=pd.read_csv("/content/adult 3.csv")
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.shape
# Out:
# (48842, 15)

# %%
data.head() #shows default first 5 rows
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data.head(8)
# Out:
#    age         workclass  fnlwgt     education  educational-num  \
# 0   25           Private  226802          11th                7
# 1   38           Private   89814       HS-grad                9
# 2   28         Local-gov  336951    Assoc-acdm               12
# 3   44           Private  160323  Some-college               10
# 4   18                 ?  103497  Some-college               10
# 5   34           Private  198693          10th                6
# 6   29                 ?  227026       HS-grad                9
# 7   63  Self-emp-not-inc  104626   Prof-school               15
#
#        marital-status         occupation   relationship   race  gender  \
# 0       Never-married  Machine-op-inspct      Own-child  Black    Male
# 1  Married-civ-spouse    Farming-fishing        Husband  White    Male
# 2  Married-civ-spouse    Protective-serv        Husband  White    Male
# 3  Married-civ-spouse  Machine-op-inspct        Husband  Black    Male
# ...

# %%
data.tail(3)
# Out:
#        age     workclass  fnlwgt education  educational-num  \
# 48839   58       Private  151910   HS-grad                9
# 48840   22       Private  201490   HS-grad                9
# 48841   52  Self-emp-inc  287927   HS-grad                9
#
#            marital-status       occupation relationship   race  gender  \
# 48839             Widowed     Adm-clerical    Unmarried  White  Female
# 48840       Never-married     Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse  Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48839             0             0              40  United-States  <=50K
# 48840             0             0              20  United-States  <=50K
# 48841         15024             0              40  United-States   >50K

# %% [markdown]
# #Null values

# %%
data.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
data.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
print(data.gender.value_counts())
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
print(data.education.value_counts())
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
print(data['marital-status'].value_counts())
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
print(data['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
data.occupation.replace({'?' : 'others'}, inplace=True)
# Out:
# /tmp/ipython-input-15-530480954.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.occupation.replace({'?' : 'others'}, inplace=True)

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
data.workclass.replace({'?' : 'notListed'}, inplace=True)
# Out:
# /tmp/ipython-input-17-2349530987.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.workclass.replace({'?' : 'notListed'}, inplace=True)

# %%
print(data['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# notListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
data=data[data['workclass']!= 'Without-pay']
data=data[data['workclass']!= 'Never-worked']
print(data['workclass'].value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# notListed            2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (48811, 15)

# %%
data=data[data['education']!= 'Preschool']
data=data[data['education']!= '1st-4th']
data=data[data['education']!= '5th-6th']

# %%
print(data.education.value_counts())
# Out:
# education
# HS-grad         15768
# Some-college    10873
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1809
# Assoc-acdm       1599
# 10th             1387
# 7th-8th           952
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (47972, 15)

# %% [markdown]
# #**Redundancy**

# %%
#redundancy
data.drop(columns=['education'], inplace=True)

# %%
data
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 0       25       Private  226802                7       Never-married
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 4       18     notListed  103497               10       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# ...

# %% [markdown]
# # **Removing Outliers**

# %%
#outlier
import matplotlib.pyplot as plt
plt.boxplot(data['age'])
plt.show()

# %%
data=data[(data['age']<=75)& (data['age']>=17)]

plt.boxplot(data['age'])
plt.show()

# %% [markdown]
# #Use encoder to convert categorical value into numerical value
# # #Label encoding

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['workclass']= encoder.fit_transform(data['workclass'])
# Out:
# /tmp/ipython-input-28-3318017705.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['workclass']= encoder.fit_transform(data['workclass'])

# %%
x=data.drop(columns=['income']) #input
y= data['income'] #output

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['workclass']= encoder.fit_transform(data['workclass'])
data['marital-status']= encoder.fit_transform(data['marital-status'])
data['occupation']= encoder.fit_transform(data['occupation'])
data['race']= encoder.fit_transform(data['race'])
data['gender']= encoder.fit_transform(data['gender'])
data['native-country']= encoder.fit_transform(data['native-country'])
data['relationship']= encoder.fit_transform(data['relationship'])
# Out:
# /tmp/ipython-input-30-4176867272.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['workclass']= encoder.fit_transform(data['workclass'])
# /tmp/ipython-input-30-4176867272.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['marital-status']= encoder.fit_transform(data['marital-status'])
# /tmp/ipython-input-30-4176867272.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...

# %%
data
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          2  226802                7               4           6
# 1       38          2   89814                9               2           4
# 2       28          1  336951               12               2          10
# 3       44          2  160323               10               2           6
# 4       18          6  103497               10               4          14
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          2  257302               12               2          12
# 48838   40          2  154374                9               2           6
# 48839   58          2  151910                9               6           0
# 48840   22          2  201490                9               4           0
# 48841   52          3  287927                9               2           3
#
# ...

# %%
x= data.drop(columns=['income'])
y= data['income']

# %%
x
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          2  226802                7               4           6
# 1       38          2   89814                9               2           4
# 2       28          1  336951               12               2          10
# 3       44          2  160323               10               2           6
# 4       18          6  103497               10               4          14
# ...    ...        ...     ...              ...             ...         ...
# 48837   27          2  257302               12               2          12
# 48838   40          2  154374                9               2           6
# 48839   58          2  151910                9               6           0
# 48840   22          2  201490                9               4           0
# 48841   52          3  287927                9               2           3
#
# ...

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48837    <=50K
# 48838     >50K
# 48839    <=50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 47619, dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
x=scaler.fit_transform(x)
x
# Out:
# array([[0.13793103, 0.33333333, 0.14512876, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.36206897, 0.33333333, 0.05245126, ..., 0.        , 0.5       ,
#         0.95121951],
#        [0.18965517, 0.16666667, 0.21964867, ..., 0.        , 0.39795918,
#         0.95121951],
#        ...,
#        [0.70689655, 0.33333333, 0.09446153, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.0862069 , 0.33333333, 0.12800425, ..., 0.        , 0.19387755,
#         0.95121951],
#        [0.60344828, 0.5       , 0.18648211, ..., 0.        , 0.39795918,
#         0.95121951]])

# %% [markdown]
# # **train_test_split**

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2, random_state=23, stratify=y)

# %%
x_train
# Out:
# array([[0.44827586, 0.33333333, 0.10248458, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.17241379, 0.16666667, 0.08567128, ..., 0.        , 0.34693878,
#         0.95121951],
#        [0.75862069, 0.66666667, 0.11752469, ..., 0.        , 0.39795918,
#         0.04878049],
#        ...,
#        [0.0862069 , 0.5       , 0.24567574, ..., 0.        , 0.39795918,
#         0.85365854],
#        [0.53448276, 0.33333333, 0.14505705, ..., 0.        , 0.39795918,
#         0.95121951],
#        [0.01724138, 0.33333333, 0.0515217 , ..., 0.        , 0.35714286,
#         0.95121951]])

# %% [markdown]
# #Machine Learning Algorithm

# %%
#using KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier()
model.fit(x_train, y_train)
predict=model.predict(x_test)
predict
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predict)
# Out:
# 0.8182486350272995

# %%
#using LogisticRegression
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train, y_train)
predict1=lr.predict (x_test)
predict1
# Out:
# array(['<=50K', '<=50K', '>50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predict1)
# Out:
# 0.8205585888282234

# %%
result = {
    'Actual':  y_test,
    'Predicted' : predict # Use the predictions from the model on the test set
}

# %%
pd.DataFrame(result)
# Out:
#       Actual Predicted
# 34316  <=50K     <=50K
# 1009   <=50K     <=50K
# 47699  <=50K      >50K
# 35856  <=50K     <=50K
# 31421  <=50K     <=50K
# ...      ...       ...
# 36843  <=50K     <=50K
# 18729  <=50K     <=50K
# 8880   <=50K     <=50K
# 4390   <=50K     <=50K
# 8066    >50K     <=50K
#
# [9524 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Predicted'].value_counts()
    for x_label, grp in _df_11.groupby('Actual')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Actual')
_ = plt.ylabel('Predicted')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-44-3992481681.py in <cell line: 0>()
#       5 df_2dhist = pd.DataFrame({
#       6     x_label: grp['Predicted'].value_counts()
# ----> 7     for x_label, grp in _df_11.groupby('Actual')
#       8 })
#       9 sns.heatmap(df_2dhist, cmap='viridis')
#
# NameError: name '_df_11' is not defined

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_10.groupby('Predicted').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_9.groupby('Actual').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#using MLPClassifier
from sklearn.neural_network import MLPClassifier
mlp=MLPClassifier(solver='adam', hidden_layer_sizes=(5,2), random_state=2,max_iter=2000)

# Fit model
mlp.fit(X_encoded, y)
predict2=lr.predict (x_test)
predict

# Save model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-4269527211.py in <cell line: 0>()
#       4
#       5 # Fit model
# ----> 6 mlp.fit(X_encoded, y)
#       7 predict2=lr.predict (x_test)
#       8 predict
#
# NameError: name 'X_encoded' is not defined

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, predict2)

# %%
y_test

# %%
y_train

# %%
result = {
    'Actual':  y_test,
    'Predicted' : predict # Use the predictions from the model on the test set
}

# %%
pd.DataFrame(result)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_6.groupby('Actual').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-4245823910.py in <cell line: 0>()
#       1 from matplotlib import pyplot as plt
#       2 import seaborn as sns
# ----> 3 _df_6.groupby('Actual').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
#       4 plt.gca().spines[['top', 'right',]].set_visible(False)
#
# NameError: name '_df_6' is not defined

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_7.groupby('Predicted').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['Predicted'].value_counts()
    for x_label, grp in _df_8.groupby('Actual')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('Actual')
_ = plt.ylabel('Predicted')

# %%
# !pip install gradio scikit-learn pandas joblib

# %%
import gradio as gr
import pandas as pd
import joblib

# Load model and encoder
model = joblib.load("model.pkl")
encoder = joblib.load("encoder.pkl")

# Define prediction function
def predict_salary(age, workclass, fnlwgt, education, educational_num, marital_status,
                   occupation, relationship, race, gender, capital_gain,
                   capital_loss, hours_per_week, native_country):
    df = pd.DataFrame({
        'age': [age],
        'workclass': [workclass],
        'fnlwgt': [fnlwgt],
        'education': [education],
        'educational-num': [educational_num],
        'marital-status': [marital_status],
        'occupation': [occupation],
        'relationship': [relationship],
        'race': [race],
        'gender': [gender],
        'capital-gain': [capital_gain],
        'capital-loss': [capital_loss],
        'hours-per-week': [hours_per_week],
        'native-country': [native_country]
    })

    df_encoded = encoder.transform(df)

    # Get probability for class 1 (>50K)
    prob = model.predict_proba(df_encoded)[0][1]

    # Set a threshold — default is 0.5, you can raise it to be more strict
    threshold = 0.5

    if prob >= threshold:
      label = ">50K"
    else:
      label = "<=50K"

    confidence = round(prob * 100, 2)

# Display prediction and confidence
    return f"{label} (Confidence: {confidence}%)"
    st.metric("Prediction Confidence", f"{confidence}%")
    st.progress(min(int(prob * 100), 100))




# Interface
gr.Interface(
    fn=predict_salary,
    inputs=[
        gr.Slider(18, 90, value=30, label="Age"),
        gr.Dropdown(['Private', 'Self-emp-not-inc', 'Self-emp-inc','State govt', 'Federal-gov', 'Local-gov'], label="Workclass"),
        gr.Number(label="Final Weight (fnlwgt)"),
        gr.Dropdown(['7th','8th','9th', '10th' ,'Bachelors', 'HS-grad', 'Masters', 'Some-college'], label="Education"),
        gr.Slider(1, 16, value=10, label="Education Num"),
        gr.Dropdown(['Never-married', 'Married-civ-spouse', 'Divorced', 'Widowed'], label="Marital Status"),
        gr.Dropdown(['Protective-serv','Tech-support','Handlers-cleaners','Adm-clerical','Prof-specialty','Craft-repair', 'Sales', 'Exec-managerial','Farming-fishing','Other-service'], label="Occupation"),
        gr.Dropdown(['Unmarried','Wife','Husband','Own-child', 'Not-in-family', 'Other-relative'], label="Relationship"),
        gr.Dropdown(['White', 'Black', 'Asian-Pac-Islander'], label="Race"),
        gr.Dropdown(['Male', 'Female'], label="Gender"),
        gr.Number(label="Capital Gain"),
        gr.Number(label="Capital Loss"),
        gr.Slider(1, 99, value=40, label="Hours per week"),
        gr.Dropdown(['United-States', 'Dominican-Republic','Germany','Philippines','Thailand','Haiti', 'Mexico', 'India', 'Others'], label="Native Country")
    ],
    outputs="text",
    title="Employee Salary Prediction"
).launch()
